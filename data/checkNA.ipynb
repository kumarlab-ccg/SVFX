# %%
import pandas as pd

# %%
df = pd.read_csv("../output_matrix_disease10000-control10000_coords.csv", sep="\t")

# %%
df
# Out:
#        Label (1 = gold standard, 0 = negative) Chromosome      Start  \
# 0                                            1         15   22770420
# 1                                            1         11   67799159
# 2                                            1         22   21465660
# 3                                            1         19   13386643
# 4                                            1          7   72722980
# ...                                        ...        ...        ...
# 19995                                        1          9  109151828
# 19996                                        1         12   81037902
# 19997                                        1          1   96996364
# 19998                                        1         16   19252184
# 19999                                        1         18   32665866
#
#              End  \
# 0       28660038
# 1       71304541
# 2       23810042
# 3       13387962
# 4       74200092
# ...          ...
# ...

# %%
df.isnull().sum()
# Out:
# Label (1 = gold standard, 0 = negative)                                      0
# Chromosome                                                                   0
# Start                                                                        0
# End                                                                          0
# 28736.Roadmap.SRS004212_Combined_Libraries_424.WGB-Seq.signal.bigWig_mean    0
# E003-DNase.pval.signal.bigwig_mean                                           0
# E003-H3K4me1.pval.signal.bigwig_mean                                         0
# E003-H3K4me3.pval.signal.bigwig_mean                                         0
# E003-H3K9me3.pval.signal.bigwig_mean                                         0
# E003-H3K27ac.pval.signal.bigwig_mean                                         0
# E003-H3K27me3.pval.signal.bigwig_mean                                        0
# E003-H3K36me3.pval.signal.bigwig_mean                                        0
# ...

# %%
df.tail(10000)["Label (1 = gold standard, 0 = negative)"] = 0
# Out:
# C:\Users\Yumika\AppData\Local\Temp\ipykernel_8852\4009539192.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.tail(10000)["Label (1 = gold standard, 0 = negative)"] = 0

# %%
df
# Out:
#        Label (1 = gold standard, 0 = negative) Chromosome      Start  \
# 0                                            1         15   22770420
# 1                                            1         11   67799159
# 2                                            1         22   21465660
# 3                                            1         19   13386643
# 4                                            1          7   72722980
# ...                                        ...        ...        ...
# 19995                                        0          9  109151828
# 19996                                        0         12   81037902
# 19997                                        0          1   96996364
# 19998                                        0         16   19252184
# 19999                                        0         18   32665866
#
#              End  \
# 0       28660038
# 1       71304541
# 2       23810042
# 3       13387962
# 4       74200092
# ...          ...
# ...

# %%
df["Label (1 = gold standard, 0 = negative)"].value_counts()
# Out:
# 0    10000
# 1    10000
# Name: Label (1 = gold standard, 0 = negative), dtype: int64

# %%
df.to_csv("../01fixed-output_matrix_disease10000-control10000_coords.csv", sep="\t", index=False)
